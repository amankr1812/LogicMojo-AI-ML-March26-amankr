# %% [markdown]
# ##REGEX

# %% [markdown]
# Q1. Division with Exception Handling
#
# Write a program that takes two numbers and safely performs division.
# Handle division by zero using try-except.

# %%
num1 = int(input("Enter number 1 "))
num2 = int(input("Enter number 2 "))
try:
    div = num1/num2
    print("Value = ",div)
except ZeroDivisionError:
    print("Zero Division Error Happened")
# Out:
# Enter number 1  10
# Enter number 2  2
# Value =  5.0

# %% [markdown]
# Q2. String to Integer Conversion
#
# Given a list:
#
# data = ["10", "20", "abc", "30"]
#
# Convert all values to integers.
# Skip invalid values using exception handling.

# %%
data = ["10", "20", "abc", "30"]
newList = []
try:
    for i in data:
        try:
            newList.append(int(i))
        except:
            print("Loop Error, Continue")
            continue
except:
    print("Error")
print("New List = ", newList)
# Out:
# Loop Error, Continue
# New List =  [10, 20, 30]

# %% [markdown]
# Q3. Multiple Exception Handling
#
# Write a program that:
#
# Takes user input
# Converts it to integer
# Divides 100 by that number
#
# Handle:
#
# ValueError
# ZeroDivisionError

# %%
try:
    num = int(input("Enter the number "))
    value = 100/num
    print("Value = ",value)
except ValueError:
    print("Incorrect Type of Value Entered")
except ZeroDivisionError:
    print("Cannot divide by zero")
# Out:
# Enter the number  10
# Value =  10.0

# %% [markdown]
# Q4. Using finally
#
# Write a program that:
#
# Opens a file (dummy)
# Prints a message
# Ensures a “Closing file” message always runs using finally

# %%
try:
    file = open("data.csv")
    data = file.read()
except:
    print("File openning error")
finally:
    print("Closing the file")
# Out:
# File openning error
# Closing the file

# %% [markdown]
# Q5. Using assert
#
# Write a program that checks if a number is positive using assert.

# %%
num = int(input("enter"))
assert num>0, "Number should be positive"
# Out:
# enter 1

# %% [markdown]
# Q6. Clean Text
#
# Given:
#
# text = "   Hello Python   "
#
# Remove spaces and convert to lowercase.

# %%
text = " Hello Python "
print(text.strip().lower())
# Out:
# hello python

# %% [markdown]
# Q7. Replace Words
#
# Replace all occurrences of "Python" with "AI" in:
#
# text = "Python is great. Python is easy."

# %%
text = "Python is great. Python is easy."
newText = text.replace("Python","AI")
print("New Text = ", newText)
# Out:
# New Text =  AI is great. AI is easy.

# %% [markdown]
# Q8. Split and Join
#
# Convert:
#
# text = "apple,banana,orange"
#
# Into:
#
# "apple banana orange"

# %%
text = "apple,banana,orange"
list = text.split(",")
print(" ".join(list))
# Out:
# apple banana orange

# %% [markdown]
# Q9. Count Words
#
# Count number of words in a sentence using split.

# %%
str = "This is a sentence that has words and numbers like 123"
list = str.split(" ")
print("Number of words = ", len(list))
# Out:
# Number of words =  11

# %% [markdown]
# Q10. Reverse Words
#
# Reverse words in a string:
#
# "I love AI"

# %%
str = "I love AI"
list = str.split(" ")
list.reverse()
print(" ".join(list))
# Out:
# AI love I

# %% [markdown]
# Q11. Find Digits
#
# Extract all digits from:
#
# text = "My number is 98765"

# %%
import re
text = "My number is 98765"
num = re.findall(r"\d+", text)
print("All Digits are ", "".join(num))
# Out:
# All Digits are  98765

# %% [markdown]
# Q12. Find Words Starting with 'a'
#
# From:
#
# text = "apple banana avocado berry"
#
# Extract words starting with 'a'.

# %%
import re
text = "apple banana avocado berry"
words = re.findall(r"\ba\w*",text)
print(words)
# Out:
# ['apple', 'avocado']

# %% [markdown]
# Q13. Extract Emails
#
# Extract emails from:
#
# text = "Contact: test@gmail.com, admin@yahoo.com"

# %%
import re
text = "Contact: test_t@gmail.com, admin@yahoo.com"
emails = re.findall(r"[\w.-]+@\w+\.\w+", text)
print(emails)
# Out:
# ['test_t@gmail.com', 'admin@yahoo.com']

# %% [markdown]
# Q14. Validate Phone Numbers
#
# Extract valid 10-digit phone numbers from:
#
# text = "Call 9876543210 or 12345"

# %%
import re
text = "Call 9876543210 or 12345"
number = re.findall(r"\d{10}", text)
print(number)
# Out:
# ['9876543210']

# %% [markdown]
# Q15. Replace Digits
#
# Replace all digits with "X" in:
#
# text = "My number is 98765"

# %%
import re
text = "My number is 98765"
newText = re.sub(r"\d+", "XXXXX", text)
print(newText)
# Out:
# My number is XXXXX

# %% [markdown]
# Q16. Extract Dates
#
# Extract date from:
#
# text = "Today is 2026-03-28"
#
# Return:
#
# Year
# Month
# Day

# %%
import re
text = "Today is 2026-03-28"
date = re.findall(r"\d{4}-\d{2}-\d{2}", text)
print(" ".join("".join(date).split("-")))
# Out:
# 2026 03 28

# %% [markdown]
# Q. 17 Extract numbers followed by "rs":
#
# text = "100rs 200usd 300rs"

# %%
import re
text = "100rs 200usd 300rs"
num = re.findall(r"(\d+)rs", text)
print(num)
# Out:
# ['100', '300']

# %% [markdown]
# Q. 18 Extract numbers that come after "rs":
#
# text = "rs100 rs200 usd300"

# %%
import re
text = "rs100 rs200 usd300"
num = re.findall(r"rs(\d+)", text)
print(num)
# Out:
# ['100', '200']

# %% [markdown]
# Q. 19 Extract Valid Transaction Records Using a Single Regex Pattern
#
# You are given a messy log string:
#
# log = """
# ID:TXN12345 | User: Mahipal_01 | Email: mahi123@gmail.com | Phone: +91-9876543210 | Amount: Rs.5000
# ID:TXN12 | User: @InvalidUser | Email: wronggmail.com | Phone: 98765 | Amount: Rs.-200
# ID:TXN99999 | User: Ravi_kumar | Email: ravi.kumar@yahoo.com | Phone: +91-9123456789 | Amount: USD300
# ID:TXN54321 | User: Sita99 | Email: sita99@gmail | Phone: +91-9999999999 | Amount: Rs.7000
#
#
# Write a single REGEX pattern that extracts ONLY VALID records where:
# CONDITIONS (VERY IMPORTANT)
# Transaction ID
# Format: TXN followed by exactly 5 digits
# Example: TXN12345
# Use: ^, {}, \d
#
# Username
# Only letters, numbers, underscore
# Must start with a letter
# Example: Mahipal_01
# Use: [a-zA-Z], \w, +
#
# Email
# Valid format: word@word.domain
# Example: test123@gmail.com
# Use: \w, ., @, +, \.
#
# Phone Number
# Format: +91-XXXXXXXXXX
# Exactly 10 digits
# Use: \+, \d, {}
#
# Amount
# Currency: Rs or USD
# Amount must be positive
# Example: Rs.5000, USD300
# Use: (rs|usd), \d+, ?
#
#
#
#
# EXPECTED OUTPUT
#
# Only valid records should match:
#
# [
# "ID:TXN12345 | User: Mahipal_01 | Email: mahi123@gmail.com | Phone: +91-9876543210 | Amount: Rs.5000",
#
# "ID:TXN99999 | User: Ravi_kumar | Email: ravi.kumar@yahoo.com | Phone: +91-9123456789 | Amount: USD300"
# ]

# %%
import re

log = """
ID:TXN12345 | User: Mahipal_01 | Email: mahi123@gmail.com | Phone: +91-9876543210 | Amount: Rs.5000
ID:TXN12 | User: @InvalidUser | Email: wronggmail.com | Phone: 98765 | Amount: Rs.-200
ID:TXN99999 | User: Ravi_kumar | Email: ravi.kumar@yahoo.com | Phone: +91-9123456789 | Amount: USD300
ID:TXN54321 | User: Sita99 | Email: sita99@gmail | Phone: +91-9999999999 | Amount: Rs.7000
"""
validRecords = re.findall(r"ID:TXN\d{5} \| User: [a-zA-Z]\w+ \| Email: [\w.-]+@\w+\.\w+ \| Phone: \+91-\d{10} \| Amount: (?:Rs\.|USD)\d+", log)
for i in validRecords:
    print(i)
# Out:
# ID:TXN12345 | User: Mahipal_01 | Email: mahi123@gmail.com | Phone: +91-9876543210 | Amount: Rs.5000
# ID:TXN99999 | User: Ravi_kumar | Email: ravi.kumar@yahoo.com | Phone: +91-9123456789 | Amount: USD300

# %% [markdown]
# **Assignment 2 Data Structures & Functions**

# %% [markdown]
# ## 1. Customer Segmentation Engine
#
# You are given a list of customer dictionaries:
#
# ```python
# customers = [
#     {"id": 1, "age": 25, "income": 50000, "spend": 20000},
#     {"id": 2, "age": 45, "income": 120000, "spend": 80000},
#     {"id": 3, "age": 35, "income": 70000, "spend": 30000}
# ]
# ```
#
# Task:
#
# 1. Write a function segment_customer(customer):
# 2. If spend divided by income is greater than 0.6 return "High Value"
# 3. If spend divided by income is between 0.3 and 0.6 return "Medium Value"
# 4. Otherwise return "Low Value"
# 5. Create a final dictionary in the format {customer_id: segment}

# %%
customers = [
    {"id": 1, "age": 25, "income": 50000, "spend": 20000},
    {"id": 2, "age": 45, "income": 120000, "spend": 80000},
    {"id": 3, "age": 35, "income": 70000, "spend": 30000}
]
final_dict = {}
def segment_customer(customer):
    id = customer.get("id")
    age = customer.get("age")
    income = customer.get("income")
    spend = customer.get("spend")

    val = spend/income
    segment = ""
    if(val>0.6):
        segment = "High Value"
    if(val>0.3 and val<0.6):
        segment = "Medium Value"
    elif (val<0.3):
        segment = "Low Value"

    final_dict[id] = segment

for i in customers:
    segment_customer(i)

print(final_dict)
# Out:
# {1: 'Medium Value', 2: 'High Value', 3: 'Medium Value'}

# %% [markdown]
# ## 2. Text Cleaning Pipeline
#
# You are given:
#
# ```python
# texts = [
#     "Hello!!! How are you???",
#     "This is    AI     class.",
#     "Python@@@is###great"
# ]
# ```
#
# Task:
#
# 1. Write a function clean_text(text):
# 2. Remove special characters
# 3. Remove extra spaces
# 4. Convert text to lowercase
# 5. Apply the function to all elements using loop or map
# 6. Return cleaned list
#
# ---

# %%
import re
texts = [
    "Hello!!! How are you???",
    "This is    AI     class.",
    "Python@@@is###great"
]

cleanedList = []
def clean_text(text):
    val = re.findall(r"[a-zA-Z0-9]+", text)
    cleaned = " ".join(val).lower()
    cleanedList.append(cleaned)

for i in texts:
    clean_text(i)

print(cleanedList)
# Out:
# ['hello how are you', 'this is ai class', 'python is great']

# %% [markdown]
# ## 3. Fraud Detection Rule Engine
#
# You are given:
#
# ```python
# transactions = [
#     {"id": 101, "amount": 5000, "location": "India"},
#     {"id": 102, "amount": 200000, "location": "Unknown"},
#     {"id": 103, "amount": 1000, "location": "India"}
# ]
# ```
#
# Task:
#
# 1. Write a function is_fraud(transaction)
# 2. If amount is greater than 100000 or location is "Unknown" mark as fraud
# 3. Otherwise mark as safe
# 4. Use lambda with filter or map
# 5. Return only fraud transactions

# %%
transactions = [
    {"id": 101, "amount": 5000, "location": "India"},
    {"id": 102, "amount": 200000, "location": "Unknown"},
    {"id": 103, "amount": 1000, "location": "India"}
]

def is_fraud(transaction):
    amt = transaction.get("amount")
    loc = transaction.get("location")
    checkAmt = False
    checkLocation = False
    checkAmt = lambda amt: amt>100000
    checkLocation = lambda loc: loc == "Unknown"
    if((checkAmt(amt) and checkLocation(loc)) is True):
        print(transaction)
    

for i in transactions:
    is_fraud(i)
# Out:
# {'id': 102, 'amount': 200000, 'location': 'Unknown'}

# %% [markdown]
# ## 4. Feature Engineering
#
# You are given:
#
# ```python
# data = [
#     {"salary": 50000, "experience": 2},
#     {"salary": 100000, "experience": 5}
# ]
# ```
#
# Task:
#
# 1. Write a function feature_engineer(record)
# 2. Add a new key salary_per_exp
# 3. salary_per_exp is salary divided by experience
# 4. Handle division by zero using conditional logic
# 5. Return updated dataset
#
# ---

# %%
data = [
    {"salary": 50000, "experience": 2},
    {"salary": 100000, "experience": 5}
]

def feature_engineer(record):
    salary = record.get("salary")
    experience = record.get("experience")
    salary_per_exp = 0
    try:
        salary_per_exp = salary/experience
    except ZeroDivisionError:
        print("Expreience is Zero")
    record["salary_per_exp"] = salary_per_exp

for i in data:
    feature_engineer(i)

print("Updated Record: ", data)
# Out:
# Updated Record:  [{'salary': 50000, 'experience': 2, 'salary_per_exp': 25000.0}, {'salary': 100000, 'experience': 5, 'salary_per_exp': 20000.0}]

# %% [markdown]
# ## 5. Custom Reduce Function
#
# You are given:
#
# ```python
# accuracies = [0.8, 0.75, 0.9, 0.85]
# ```
#
# Task:
#
# 1. Use reduce function to calculate average accuracy
# 2. Do not use sum function
# 3. Show intermediate logic using a custom function

# %%
from functools import reduce

accuracies = [0.8, 0.75, 0.9, 0.85]
total = reduce(lambda x,y: (x+y),accuracies)
average = total/len(accuracies)
print("Average : ", average)
# Out:
# Average :  0.8250000000000001

# %% [markdown]
# ## 6. Sequence Pattern Detection
#
# You are given:
#
# ```python
# data = [10, 20, 30, 25, 40, 50]
# ```
#
# Task:
#
# 1. Write a function detect_increasing_sequence(data)
# 2. Find the longest continuous increasing sequence
# 3. Return that sequence as a list
#
# Example output:
#
# ```python
# [10, 20, 30]
# ```

# %%
data = [10, 20, 30, 25, 40, 50]

def detect_increasing_sequence(data):
    #Not able to figure out the logic

# %% [markdown]
# ## 7. Dictionary-Based Recommendation System
#
# You are given:
#
# ```python
# user_purchases = {
#     "user1": ["apple", "banana"],
#     "user2": ["banana", "orange"],
#     "user3": ["apple", "orange"]
# }
# ```
#
# Task:
#
# 1. Write a function recommend(user)
# 2. Recommend items based on common items between users
# 3. Do not recommend items already purchased by the user
# 4. Use sets and dictionary iteration
#
# ---

# %%
user_purchases = {
    "user1": ["apple", "banana"],
    "user2": ["banana", "orange"],
    "user3": ["apple", "orange"]
}

def recommended(user):
    #Not able to understand the requirement, need further clarification

# %% [markdown]
# ## 8. Recursive Decision Tree Simulation
#
# Task:
#
# 1. Write a recursive function decision_tree(score)
# 2. If score is greater than 80 return "Approved"
# 3. If score is between 50 and 80 call the function again with score plus 10
# 4. If score is less than 50 return "Rejected"
#
# ---

# %%
def decision_tree(score):
    if(score>80):
        return "Approved"
    elif(score>=50 and score<=80):
        return decision_tree(score+10)
    elif(score<50):
        return "Rejected"

score = int(input("Enter Score"))
print(decision_tree(score))
# Out:
# Enter Score 55
# Approved
